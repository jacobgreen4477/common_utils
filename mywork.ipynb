# %% [markdown]
# - title : sample mywork
# - author : hjy
#
# > git config --global user.name "jacobgreen4477" <br>
# > git config --global user.email "jacobgreen4477@gmail.com" <br>

# %%
import pandas as pd 
import numpy as np
